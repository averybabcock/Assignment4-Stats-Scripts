# %% [markdown]
# # Boxplots and paired differences

# %% [markdown]
# ### Importing pandas tool and getting the csv file

# %%
import pandas
data = pandas.read_csv('brain_size.csv', sep=';', na_values=".")
data
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0            1  Female   133  132  124   118.0    64.5     816932
# 1            2    Male   140  150  124     NaN    72.5    1001121
# 2            3    Male   139  123  150   143.0    73.3    1038437
# 3            4    Male   133  129  128   172.0    68.8     965353
# 4            5  Female   137  132  134   147.0    65.0     951545
# 5            6  Female    99   90  110   146.0    69.0     928799
# 6            7  Female   138  136  131   138.0    64.5     991305
# 7            8  Female    92   90   98   175.0    66.0     854258
# 8            9    Male    89   93   84   134.0    66.3     904858
# 9           10    Male   133  114  147   172.0    68.8     955466
# 10          11  Female   132  129  124   118.0    64.5     833868
# 11          12    Male   141  150  128   151.0    70.0    1079549
# 12          13    Male   135  129  124   155.0    69.0     924059
# 13          14  Female   140  120  147   155.0    70.5     856472
# 14          15  Female    96  100   90   146.0    66.0     878897
# 15          16  Female    83   71   96   135.0    68.0     865363
# 16          17  Female   132  132  120   127.0    68.5     852244
# 17          18    Male   100   96  102   178.0    73.5     945088
# 18          19  Female   101  112   84   136.0    66.3     808020
# 19          20    Male    80   77   86   180.0    70.0     889083
# 20          21    Male    83   83   86     NaN     NaN     892420
# 21          22    Male    97  107   84   186.0    76.5     905940
# 22          23  Female   135  129  134   122.0    62.0     790619
# 23          24    Male   139  145  128   132.0    68.0     955003
# 24          25  Female    91   86  102   114.0    63.0     831772
# 25          26    Male   141  145  131   171.0    72.0     935494
# 26          27  Female    85   90   84   140.0    68.0     798612
# 27          28    Male   103   96  110   187.0    77.0    1062462
# 28          29  Female    77   83   72   106.0    63.0     793549
# 29          30  Female   130  126  124   159.0    66.5     866662
# 30          31  Female   133  126  132   127.0    62.5     857782
# 31          32    Male   144  145  137   191.0    67.0     949589
# 32          33    Male   103   96  110   192.0    75.5     997925
# 33          34    Male    90   96   86   181.0    69.0     879987
# 34          35  Female    83   90   81   143.0    66.5     834344
# 35          36  Female   133  129  128   153.0    66.5     948066
# 36          37    Male   140  150  124   144.0    70.5     949395
# 37          38  Female    88   86   94   139.0    64.5     893983
# 38          39    Male    81   90   74   148.0    74.0     930016
# 39          40    Male    89   91   89   179.0    75.5     935863

# %% [markdown]
# ### Creating from arrays from numpy

# %%
import numpy as np
t = np.linspace(-6, 6, 20)
sin_t = np.sin(t)
cos_t = np.cos(t)

# %% [markdown]
# ### Expose them as pandas.DataFrame

# %%
pandas.DataFrame({'t': t, 'sin': sin_t, 'cos': cos_t})
# Out:
#            t       sin       cos
# 0  -6.000000  0.279415  0.960170
# 1  -5.368421  0.792419  0.609977
# 2  -4.736842  0.999701  0.024451
# 3  -4.105263  0.821291 -0.570509
# 4  -3.473684  0.326021 -0.945363
# 5  -2.842105 -0.295030 -0.955488
# 6  -2.210526 -0.802257 -0.596979
# 7  -1.578947 -0.999967 -0.008151
# 8  -0.947368 -0.811882  0.583822
# 9  -0.315789 -0.310567  0.950551
# 10  0.315789  0.310567  0.950551
# 11  0.947368  0.811882  0.583822
# 12  1.578947  0.999967 -0.008151
# 13  2.210526  0.802257 -0.596979
# 14  2.842105  0.295030 -0.955488
# 15  3.473684 -0.326021 -0.945363
# 16  4.105263 -0.821291 -0.570509
# 17  4.736842 -0.999701  0.024451
# 18  5.368421 -0.792419  0.609977
# 19  6.000000 -0.279415  0.960170

# %% [markdown]
# ### Collect information on the rows and columns on the graph

# %%
data.shape    # 40 rows and 8 columns
# Out:
# (40, 8)

# %%
data.columns  # It has columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height',
#        'MRI_Count'],
#       dtype='object')

# %% [markdown]
# Print the column Gender from the csv file

# %%
print(data['Gender'])  # Columns can be addressed by name
# Out:
# 0     Female
# 1       Male
# 2       Male
# 3       Male
# 4     Female
# 5     Female
# 6     Female
# 7     Female
# 8       Male
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13    Female
# 14    Female
# 15    Female
# 16    Female
# 17      Male
# 18    Female
# 19      Male
# 20      Male
# 21      Male
# 22    Female
# 23      Male
# 24    Female
# 25      Male
# 26    Female
# 27      Male
# 28    Female
# 29    Female
# 30    Female
# 31      Male
# 32      Male
# 33      Male
# 34    Female
# 35    Female
# 36      Male
# 37    Female
# 38      Male
# 39      Male
# Name: Gender, dtype: object

# %%
# Simpler selector
data[data['Gender'] == 'Female']['VIQ'].mean()
# Out:
# np.float64(109.45)

# %% [markdown]
# ### Splitting data into catagorical variables

# %%
groupby_gender = data.groupby('Gender')
for gender, value in groupby_gender['VIQ']:
    print((gender, value.mean()))
# Out:
# ('Female', np.float64(109.45))
# ('Male', np.float64(115.25))

# %%
groupby_gender.mean()
# Out:
#         Unnamed: 0   FSIQ     VIQ     PIQ      Weight     Height  MRI_Count
# Gender
# Female       19.65  111.9  109.45  110.45  137.200000  65.765000   862654.6
# Male         21.35  115.0  115.25  111.60  166.444444  71.431579   954855.4

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### What is the mean value for VIQ for the full population?

# %%
mean_viq = data['VIQ'].mean()

print(f"The mean VIQ for the full population is: {mean_viq}")
# Out:
# The mean VIQ for the full population is: 112.35

# %% [markdown]
# ### How many males/females were included in this study?

# %%
gender_counts = data['Gender'].value_counts()

print(gender_counts)
# Out:
# Gender
# Female    20
# Male      20
# Name: count, dtype: int64

# %% [markdown]
# ### What is the average value of MRI counts expressed in log units, for males and females

# %%
average_mri_by_gender = data.groupby('Gender')['MRI_Count'].mean()

print(average_mri_by_gender)
# Out:
# Gender
# Female    862654.6
# Male      954855.4
# Name: MRI_Count, dtype: float64

# %% [markdown]
# ### Plotting the data using pandas and matplotlib. This uses the data from the csv to make the scatter plot

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
scatter_matrix(data[['Weight', 'Height', 'MRI_Count']])
plt.show()

# %%
scatter_matrix(data[['PIQ', 'VIQ', 'FSIQ']])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ### Plot the scatter matrix for males only, and for females only. Do you think that the 2 sub-populations correspond to gender?

# %%
males = data[data['Gender'] == 'Male']
females = data[data['Gender'] == 'Female']

# --- Males ---

# Scatter matrix for physical features (males)
scatter_matrix(males[['Weight', 'Height', 'MRI_Count']])
plt.suptitle("Scatter Matrix - Males (Weight, Height, MRI_Count)")
plt.show()

# Scatter matrix for IQ scores (males)
scatter_matrix(males[['PIQ', 'VIQ', 'FSIQ']])
plt.suptitle("Scatter Matrix - Males (PIQ, VIQ, FSIQ)")
plt.show()

# --- Females ---

# Scatter matrix for physical features (females)
scatter_matrix(females[['Weight', 'Height', 'MRI_Count']])
plt.suptitle("Scatter Matrix - Females (Weight, Height, MRI_Count)")
plt.show()

# Scatter matrix for IQ scores (females)
scatter_matrix(females[['Weight', 'Height', 'MRI_Count']])
plt.suptitle("Scatter Matrix - Females (PIQ, VIQ, FSIQ)")
plt.show()

# %% [markdown]
# ## 3.1.2.Hypothesis testing: Comparing two groups

# %% [markdown]
# ### To do simple tests, we are using a subset of scipy (stats)

# %%
from scipy import stats

# %% [markdown]
# ### 1-sample T-test

# %%
stats.ttest_1samp(data['VIQ'], 0)
# Out:
# TtestResult(statistic=np.float64(30.08809997084933), pvalue=np.float64(1.3289196468727879e-28), df=np.int64(39))

# %% [markdown]
# ### 2-sample t-test

# %%
female_viq = data[data['Gender'] == 'Female']['VIQ']

# %%
male_viq = data[data['Gender'] == 'Male']['VIQ']

# %%
stats.ttest_ind(female_viq, male_viq)
# Out:
# TtestResult(statistic=np.float64(-0.7726161723275012), pvalue=np.float64(0.44452876778583217), df=np.float64(38.0))

# %% [markdown]
# ## 3.1.2.2. Paired tests: repeated measurements on the same individuals

# %% [markdown]
# ### Test if FISQ and PIQ are significantly different using a 2 sample test

# %%
stats.ttest_ind(data['FSIQ'], data['PIQ'])
# Out:
# TtestResult(statistic=np.float64(0.465637596380964), pvalue=np.float64(0.6427725009414841), df=np.float64(78.0))

# %% [markdown]
# ### Account for links between FSIQ and PIQ using a pared t-test

# %%
stats.ttest_rel(data['FSIQ'], data['PIQ'])
# Out:
# TtestResult(statistic=np.float64(1.7842019405859857), pvalue=np.float64(0.08217263818364236), df=np.int64(39))

# %% [markdown]
# ### Equivalent to a 1-sample test

# %%
stats.ttest_1samp(data['FSIQ'] - data['PIQ'], 0)
# Out:
# TtestResult(statistic=np.float64(1.7842019405859857), pvalue=np.float64(0.08217263818364236), df=np.int64(39))

# %% [markdown]
# ### Use a Wilcoxon signed-rank test to relax the T-tests assumption of Gaussian errors

# %%
stats.wilcoxon(data['FSIQ'], data['PIQ'])
# Out:
# WilcoxonResult(statistic=np.float64(274.5), pvalue=np.float64(0.10659492713506856))

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# ### Test the difference between weights in males and females.

# %%
female_weight = data[data['Gender'] == 'Female']['Weight'].dropna()
male_weight = data[data['Gender'] == 'Male']['Weight'].dropna()
result = stats.ttest_ind(female_weight, male_weight, equal_var=False)  # Welch's t-test is safer
print(result)
# Out:
# TtestResult(statistic=np.float64(-4.827378552057042), pvalue=np.float64(2.9649003096009486e-05), df=np.float64(33.50678044084757))

# %% [markdown]
# ### Use non parametric statistics to test the difference between VIQ in males and females.

# %% [markdown]
# ## 3.1.3.1. Linear models, multiple factors, and analysis of varience

# %% [markdown]
# ### Generates simulated data according to the model

# %%
import numpy as np
x = np.linspace(-5, 5, 20)
np.random.seed(1)
# normal distributed noise
y = -5 + 3*x + 4 * np.random.normal(size=x.shape)
# Create a data frame containing all the relevant variables
data = pandas.DataFrame({'x': x, 'y': y})

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from statsmodels) (2.2.6)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from statsmodels) (2.3.0)
# Requirement already satisfied: patsy>=0.5.6 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %% [markdown]
# ### Specify an OLS model and fit it

# %%
from statsmodels.formula.api import ols
model = ols("y ~ x", data=data).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     74.03
# Date:                Wed, 16 Jul 2025   Prob (F-statistic):           8.56e-08
# Time:                        21:06:59   Log-Likelihood:                -57.988
# No. Observations:                  20   AIC:                             120.0
# Df Residuals:                      18   BIC:                             122.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.5335      1.036     -5.342      0.000      -7.710      -3.357
# x              2.9369      0.341      8.604      0.000       2.220       3.654
# ==============================================================================
# Omnibus:                        0.100   Durbin-Watson:                   2.956
# Prob(Omnibus):                  0.951   Jarque-Bera (JB):                0.322
# Skew:                          -0.058   Prob(JB):                        0.851
# Kurtosis:                       2.390   Cond. No.                         3.03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# ### Retrieve the estimated parameters from the model above

# %%
intercept = model.params['Intercept']
slope = model.params['x']
print(intercept)
print(slope)
# Out:
# -5.533458545842917
# 2.93688831554405

# %% [markdown]
# ### Going back to using the brain_size data

# %%
data = pandas.read_csv('brain_size.csv', sep=';', na_values=".")

# %% [markdown]
# ### Comparison between IQ of male vs. female

# %% [markdown]
# model = ols("VIQ ~ Gender + 1", data).fit()
# print(model.summary())

# %% [markdown]
# ### An integer column can be forced to be treated as categorical using

# %%
model = ols('VIQ ~ C(Gender)', data).fit()

# %% [markdown]
# ### Link to t-tests between differrent FSIQ and PIQ

# %%
data_fisq = pandas.DataFrame({'iq': data['FSIQ'], 'type': 'fsiq'})
data_piq = pandas.DataFrame({'iq': data['PIQ'], 'type': 'piq'})
data_long = pandas.concat((data_fisq, data_piq))
print(data_long)
# Out:
#      iq  type
# 0   133  fsiq
# 1   140  fsiq
# 2   139  fsiq
# 3   133  fsiq
# 4   137  fsiq
# ..  ...   ...
# 35  128   piq
# 36  124   piq
# 37   94   piq
# 38   74   piq
# 39   89   piq
#
# [80 rows x 2 columns]

# %%
model = ols("iq ~ type", data_long).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     iq   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2168
# Date:                Wed, 16 Jul 2025   Prob (F-statistic):              0.643
# Time:                        21:16:44   Log-Likelihood:                -364.35
# No. Observations:                  80   AIC:                             732.7
# Df Residuals:                      78   BIC:                             737.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     113.4500      3.683     30.807      0.000     106.119     120.781
# type[T.piq]    -2.4250      5.208     -0.466      0.643     -12.793       7.943
# ==============================================================================
# Omnibus:                      164.598   Durbin-Watson:                   1.531
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.062
# Skew:                          -0.110   Prob(JB):                       0.0178
# Kurtosis:                       1.461   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Can see that we retrieve the same values for t-test and corresponding p-values for the effect of the type of iq than the previous t-test

# %%
stats.ttest_ind(data['FSIQ'], data['PIQ'])
# Out:
# TtestResult(statistic=np.float64(0.465637596380964), pvalue=np.float64(0.6427725009414841), df=np.float64(78.0))

# %% [markdown]
# ## 3.1.3.2 Multiple Regression: including multiple factors

# %% [markdown]
# ### Read the iris.csv in and set the model

# %%
data = pandas.read_csv('iris.csv')

# %%
model = ols('sepal_width ~ name + petal_length', data).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            sepal_width   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.468
# Method:                 Least Squares   F-statistic:                     44.63
# Date:                Wed, 16 Jul 2025   Prob (F-statistic):           1.58e-20
# Time:                        21:16:52   Log-Likelihood:                -38.185
# No. Observations:                 150   AIC:                             84.37
# Df Residuals:                     146   BIC:                             96.41
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.9813      0.099     29.989      0.000       2.785       3.178
# name[T.versicolor]    -1.4821      0.181     -8.190      0.000      -1.840      -1.124
# name[T.virginica]     -1.6635      0.256     -6.502      0.000      -2.169      -1.158
# petal_length           0.2983      0.061      4.920      0.000       0.178       0.418
# ==============================================================================
# Omnibus:                        2.868   Durbin-Watson:                   1.753
# Prob(Omnibus):                  0.238   Jarque-Bera (JB):                2.885
# Skew:                          -0.082   Prob(JB):                        0.236
# Kurtosis:                       3.659   Cond. No.                         54.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## 3.1.3.3. Post-hoc hypothesis testing: analysis of variance (ANOVA)

# %% [markdown]
# ## F-test to test the vector of contrast

# %%
print(model.f_test([0, 1, -1, 0]))
# Out:
# <F test: F=3.245335346574177, p=0.0736905878170114, df_denom=146, df_num=1>

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# ### Going back to the brain size + IQ data, test if the VIQ of male and female are different after removing the effect of brain size, height and weight

# %%
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols
data = pandas.read_csv("brain_size.csv", sep=";", na_values=".")
model = smf.ols('VIQ ~ MRI_Count + Height + Weight + Gender', data=data).fit()

# Show the summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    VIQ   R-squared:                       0.249
# Model:                            OLS   Adj. R-squared:                  0.158
# Method:                 Least Squares   F-statistic:                     2.733
# Date:                Wed, 16 Jul 2025   Prob (F-statistic):             0.0455
# Time:                        21:33:12   Log-Likelihood:                -167.03
# No. Observations:                  38   AIC:                             344.1
# Df Residuals:                      33   BIC:                             352.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        169.7719     90.054      1.885      0.068     -13.443     352.987
# Gender[T.Male]    10.1579     10.891      0.933      0.358     -12.001      32.317
# MRI_Count          0.0002   6.48e-05      2.489      0.018    2.94e-05       0.000
# Height            -2.7337      1.410     -1.938      0.061      -5.603       0.136
# Weight            -0.1427      0.215     -0.665      0.511      -0.579       0.294
# ==============================================================================
# Omnibus:                        5.002   Durbin-Watson:                   2.272
# Prob(Omnibus):                  0.082   Jarque-Bera (JB):                1.892
# Skew:                          -0.066   Prob(JB):                        0.388
# Kurtosis:                       1.915   Cond. No.                     2.41e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.41e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## 3.1.4. More Visualization: seaborn for statistical exploration

# %%
print(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width       name
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 3.1.3.1. Pairplot: scatter matrices

# %% [markdown]
# ### Intuition on interactions by using seaborn. Then will use seaborn.pairlot to display a scatter plot

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /users/PAS2797/averybabcock/.conda/envs/7030_class_1/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import urllib.request
import os

import matplotlib.pyplot as plt

# %%
if not os.path.exists('wages.txt'):
    urllib.request.urlretrieve(
        'http://lib.stat.cmu.edu/datasets/CPS_85_Wages',
        'wages.txt'
    )
# Give names to the columns
names = [
    'EDUCATION: Number of years of education',
    'SOUTH: 1=Person lives in South, 0=Person lives elsewhere',
    'SEX: 1=Female, 0=Male',
    'EXPERIENCE: Number of years of work experience',
    'UNION: 1=Union member, 0=Not union member',
    'WAGE: Wage (dollars per hour)',
    'AGE: years',
    'RACE: 1=Other, 2=Hispanic, 3=White',
    'OCCUPATION: 1=Management, 2=Sales, 3=Clerical, 4=Service, 5=Professional, 6=Other',
    'SECTOR: 0=Other, 1=Manufacturing, 2=Construction',
    'MARR: 0=Unmarried,  1=Married',
]
short_names = [n.split(':')[0] for n in names]

data = pandas.read_csv('wages.txt', skiprows=27, skipfooter=6, sep=None,
                       header=None)
data.columns = short_names
# Out:
# /tmp/slurmtmp.1688701/ipykernel_3625436/4135314094.py:22: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pandas.read_csv('wages.txt', skiprows=27, skipfooter=6, sep=None,

# %%
# Log-transform the wages, because they typically are increased with
# multiplicative factors
import numpy as np
data['WAGE'] = np.log10(data['WAGE'])

# %%
import seaborn
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg')

seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg', hue='SEX')
plt.suptitle('Effect of gender: 1=Female, 0=Male')

seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg', hue='RACE')
plt.suptitle('Effect of race: 1=Other, 2=Hispanic, 3=White')

seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg', hue='UNION')
plt.suptitle('Effect of union: 1=Union member, 0=Not union member')
# Out:
# Text(0.5, 0.98, 'Effect of union: 1=Union member, 0=Not union member')

# %%
seaborn.lmplot(y='WAGE', x='EDUCATION', data=data)

plt.show()

# %%
import seaborn

# %%
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                 kind='reg')

# %%
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                 kind='reg', hue='SEX')

# %%
from matplotlib import pyplot as plt

# %%
plt.rcdefaults()

# %% [markdown]
# ## 3.1.4.2 Implot: plotting a univariate regression

# %% [markdown]
# ### Regression with the relation between wage and education plotted using seaborn.lmplot()

# %%
seaborn.lmplot(y='WAGE', x='EDUCATION', data=data)

# %% [markdown]
# ## 3.1.5. Testing for interactions

# %%
import statsmodels.formula.api as smf
result = smf.ols('WAGE ~ EDUCATION + SEX + EDUCATION * SEX', data=data).fit()    
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGE   R-squared:                       0.198
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     43.72
# Date:                Wed, 16 Jul 2025   Prob (F-statistic):           2.94e-25
# Time:                        21:34:28   Log-Likelihood:                 88.503
# No. Observations:                 534   AIC:                            -169.0
# Df Residuals:                     530   BIC:                            -151.9
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.5748      0.058      9.861      0.000       0.460       0.689
# EDUCATION         0.0281      0.004      6.411      0.000       0.019       0.037
# SEX              -0.2750      0.093     -2.972      0.003      -0.457      -0.093
# EDUCATION:SEX     0.0134      0.007      1.919      0.056      -0.000       0.027
# ==============================================================================
# Omnibus:                        4.838   Durbin-Watson:                   1.825
# Prob(Omnibus):                  0.089   Jarque-Bera (JB):                5.000
# Skew:                          -0.156   Prob(JB):                       0.0821
# Kurtosis:                       3.356   Cond. No.                         170.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
